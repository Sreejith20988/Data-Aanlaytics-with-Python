# %%
import pandas as pd

# %%
nyc_ab = pd.read_csv("AB_NYC_2019.csv",low_memory = False)

# %%
print(list(nyc_ab))
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
type(nyc_ab)
# Out:
# pandas.core.frame.DataFrame

# %%
nyc_ab.shape
# Out:
# (48895, 16)

# %%
nyc_ab.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
nyc_ab.name
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
# 5                Large Cozy 1 BR Apartment In Midtown East
# 6                                          BlissArtsSpace!
# 7                         Large Furnished Room Near B'way
# 8                       Cozy Clean Guest Room - Family Apt
# 9                       Cute & Cozy Lower East Side 1 bdrm
# 10                        Beautiful 1br on Upper West Side
# 11                         Central Manhattan/near Broadway
# 12          Lovely Room 1, Garden, Best Area, Legal rental
# 13        Wonderful Guest Bedroom in Manhattan for SINGLES
# 14                           West Village Nest - Superhost
# 15                        Only 2 stops to Manhattan studio
# ...

# %%
nyc_ab['name']
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
# 5                Large Cozy 1 BR Apartment In Midtown East
# 6                                          BlissArtsSpace!
# 7                         Large Furnished Room Near B'way
# 8                       Cozy Clean Guest Room - Family Apt
# 9                       Cute & Cozy Lower East Side 1 bdrm
# 10                        Beautiful 1br on Upper West Side
# 11                         Central Manhattan/near Broadway
# 12          Lovely Room 1, Garden, Best Area, Legal rental
# 13        Wonderful Guest Bedroom in Manhattan for SINGLES
# 14                           West Village Nest - Superhost
# 15                        Only 2 stops to Manhattan studio
# ...

# %%
nyc_ab['name'][100]
# Out:
# 'loft bed - near transportation-15min to times sq'

# %%
nyc_ab.name[100]
# Out:
# 'loft bed - near transportation-15min to times sq'

# %%
nyc_ab.loc[100,'name']
# Out:
# 'loft bed - near transportation-15min to times sq'

# %%
nyc_ab.iloc[0]
# Out:
# id                                                              2539
# name                              Clean & quiet apt home by the park
# host_id                                                         2787
# host_name                                                       John
# neighbourhood_group                                         Brooklyn
# neighbourhood                                             Kensington
# latitude                                                     40.6475
# longitude                                                   -73.9724
# room_type                                               Private room
# price                                                            149
# minimum_nights                                                     1
# number_of_reviews                                                  9
# last_review                                               2018-10-19
# reviews_per_month                                               0.21
# ...

# %%
nyc_ab.iloc[:,1:3]
# Out:
#                                                     name    host_id
# 0                     Clean & quiet apt home by the park       2787
# 1                                  Skylit Midtown Castle       2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 5              Large Cozy 1 BR Apartment In Midtown East       7322
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# 9                     Cute & Cozy Lower East Side 1 bdrm       7549
# 10                      Beautiful 1br on Upper West Side       7702
# 11                       Central Manhattan/near Broadway       7989
# 12        Lovely Room 1, Garden, Best Area, Legal rental       9744
# ...

# %%
nyc_ab.iloc[0:3,1:3]
# Out:
#                                   name  host_id
# 0   Clean & quiet apt home by the park     2787
# 1                Skylit Midtown Castle     2845
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632

# %%
nyc_ab.iloc[[1,2,3,4],0]
# Out:
# 1    2595
# 2    3647
# 3    3831
# 4    5022
# Name: id, dtype: int64

# %%
nyc_ab.iloc[0,[1,2,3]]
# Out:
# name         Clean & quiet apt home by the park
# host_id                                    2787
# host_name                                  John
# Name: 0, dtype: object

# %%
nyc_ab.loc[1:5,'name']
# Out:
# 1                               Skylit Midtown Castle
# 2                 THE VILLAGE OF HARLEM....NEW YORK !
# 3                     Cozy Entire Floor of Brownstone
# 4    Entire Apt: Spacious Studio/Loft by central park
# 5           Large Cozy 1 BR Apartment In Midtown East
# Name: name, dtype: object

# %%
nyc_ab.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
nyc_ab[nyc_ab.neighbourhood_group == 'Brooklyn'][['name','neighbourhood','room_type','price']]
# Out:
#                                                     name  \
# 0                     Clean & quiet apt home by the park
# 3                        Cozy Entire Floor of Brownstone
# 6                                        BlissArtsSpace!
# 12        Lovely Room 1, Garden, Best Area, Legal rental
# 15                      Only 2 stops to Manhattan studio
# 16                     Perfect for Your Parents + Garden
# 18       Hip Historic Brownstone Apartment with Backyard
# 20                      Sweet and Spacious Brooklyn Loft
# 21                        CBG CtyBGd HelpsHaiti rm#1:1-4
# 22                              CBG Helps Haiti Room#2.5
# 23                                 CBG Helps Haiti Rm #2
# 24                MAISON DES SIRENES1,bohemian apartment
# 25                    Sunny Bedroom Across Prospect Park
# 32                     Loft in Williamsburg Area w/ Roof
# 34                                 Large B&B Style rooms
# ...

# %%
nyc_ab[(nyc_ab.neighbourhood_group == 'Brooklyn') & (nyc_ab.price > 199)][['name','neighbourhood','room_type','price']]
# Out:
#                                                     name  \
# 16                     Perfect for Your Parents + Garden
# 20                      Sweet and Spacious Brooklyn Loft
# 52                            * ORIGINAL BROOKLYN LOFT *
# 63            Comfortable 4-bedroom apt in family house.
# 66     Light-filled 2B duplex in the heart of Park Sl...
# 68     *HAVEN LOFT - Entire Floor - Six Windows - Bri...
# 85                   perfect for a family or small group
# 93                      2-bed brownstone duplex + garden
# 105                           Beautiful Duplex Apartment
# 109    Sunny 2-story Brooklyn townhouse w deck and ga...
# 116                  2 story family home in Williamsburg
# 121                     3 Story Town House in Park Slope
# 140                      Modern Greenpoint, Brooklyn Apt
# 158                     Luxury Brownstone in Boerum Hill
# 163                   Luxurious Condo in DUBMO with View
# ...

# %%
nyc_ab[(nyc_ab.neighbourhood_group == 'Brooklyn') | (nyc_ab.neighbourhood_group == 'Manhattan')][['name','neighbourhood','room_type','price']]
# Out:
#                                                     name       neighbourhood  \
# 0                     Clean & quiet apt home by the park          Kensington
# 1                                  Skylit Midtown Castle             Midtown
# 2                    THE VILLAGE OF HARLEM....NEW YORK !              Harlem
# 3                        Cozy Entire Floor of Brownstone        Clinton Hill
# 4       Entire Apt: Spacious Studio/Loft by central park         East Harlem
# 5              Large Cozy 1 BR Apartment In Midtown East         Murray Hill
# 6                                        BlissArtsSpace!  Bedford-Stuyvesant
# 7                       Large Furnished Room Near B'way       Hell's Kitchen
# 8                     Cozy Clean Guest Room - Family Apt     Upper West Side
# 9                     Cute & Cozy Lower East Side 1 bdrm           Chinatown
# 10                      Beautiful 1br on Upper West Side     Upper West Side
# ...

# %%
nyc_ab['state'] = 'NY'

# %%
nyc_ab['state']
# Out:
# 0        NY
# 1        NY
# 2        NY
# 3        NY
# 4        NY
# 5        NY
# 6        NY
# 7        NY
# 8        NY
# 9        NY
# 10       NY
# 11       NY
# 12       NY
# 13       NY
# 14       NY
# 15       NY
# 16       NY
# 17       NY
# 18       NY
# 19       NY
# 20       NY
# 21       NY
# 22       NY
# 23       NY
# 24       NY
# 25       NY
# 26       NY
# 27       NY
# 28       NY
# 29       NY
#          ..
# 48865    NY
# 48866    NY
# 48867    NY
# 48868    NY
# 48869    NY
# 48870    NY
# 48871    NY
# 48872    NY
# 48873    NY
# 48874    NY
# 48875    NY
# 48876    NY
# 48877    NY
# 48878    NY
# 48879    NY
# 48880    NY
# 48881    NY
# 48882    NY
# 48883    NY
# 48884    NY
# 48885    NY
# 48886    NY
# 48887    NY
# 48888    NY
# 48889    NY
# 48890    NY
# 48891    NY
# 48892    NY
# 48893    NY
# 48894    NY
# Name: state, Length: 48895, dtype: object

# %%
nyc_ab['price_c'] = nyc_ab['price']

# %%
nyc_ab.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
nyc_ab.price_c.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
nyc_ab.host_name.describe()
# Out:
# count       48874
# unique      11452
# top       Michael
# freq          417
# Name: host_name, dtype: object

# %%
nyc_ab.host_name.value_counts()
# Out:
# Michael             417
# David               403
# Sonder (NYC)        327
# John                294
# Alex                279
# Blueground          232
# Sarah               227
# Daniel              226
# Jessica             205
# Maria               204
# Mike                194
# Andrew              190
# Anna                187
# Laura               182
# Chris               182
# Melissa             160
# Emily               157
# Jennifer            154
# James               151
# Rachel              146
# Kara                143
# Amy                 142
# Jonathan            142
# Jason               140
# Michelle            140
# Brian               140
# Mark                139
# Adam                139
# Ben                 135
# Anthony             134
#                    ...
# Aspano                1
# Narmeen               1
# Zana                  1
# Lindsay Alexa         1
# Marsha & Jakob        1
# Jack And Rachel       1
# Roberto  Mike         1
# ...

# %%
nyc_ab_price_mp = nyc_ab.price_c.mean()

# %%
nyc_ab.price_c.map(lambda p:p - nyc_ab_price_mp)
# Out:
# 0         -3.720687
# 1         72.279313
# 2         -2.720687
# 3        -63.720687
# 4        -72.720687
# 5         47.279313
# 6        -92.720687
# 7        -73.720687
# 8        -73.720687
# 9         -2.720687
# 10       -17.720687
# 11       -67.720687
# 12       -63.720687
# 13       -67.720687
# 14       -32.720687
# 15       -12.720687
# 16        62.279313
# 17       -12.720687
# 18       -53.720687
# 19        37.279313
# 20       146.279313
# 21       -22.720687
# 22       -72.720687
# 23       -42.720687
# 24       -32.720687
# 25       -92.720687
# 26       -72.720687
# 27        -2.720687
# 28      -108.720687
# 29        27.279313
#             ...
# 48865    -72.720687
# 48866    -94.720687
# 48867   -127.720687
# 48868   -127.720687
# 48869   -107.720687
# 48870    -53.720687
# 48871   -117.720687
# 48872    107.279313
# 48873     17.279313
# 48874   -102.720687
# 48875    -12.720687
# 48876    -92.720687
# 48877   -110.720687
# 48878   -107.720687
# ...

# %%
nyc_ab.price.mean()
# Out:
# 152.7206871868289

# %%
nyc_ab.loc[:,['price','price_c']]
# Out:
#        price  price_c
# 0        149      149
# 1        225      225
# 2        150      150
# 3         89       89
# 4         80       80
# 5        200      200
# 6         60       60
# 7         79       79
# 8         79       79
# 9        150      150
# 10       135      135
# 11        85       85
# 12        89       89
# 13        85       85
# 14       120      120
# 15       140      140
# 16       215      215
# 17       140      140
# 18        99       99
# 19       190      190
# 20       299      299
# 21       130      130
# 22        80       80
# 23       110      110
# 24       120      120
# 25        60       60
# 26        80       80
# 27       150      150
# 28        44       44
# 29       180      180
# ...      ...      ...
# 48865     80       80
# 48866     58       58
# 48867     25       25
# 48868     25       25
# 48869     45       45
# 48870     99       99
# 48871     35       35
# 48872    260      260
# 48873    170      170
# ...

# %%
def align_price(row):
    row.price_c = row.price_c - nyc_ab_price_mp
    return row

nyc_ab = nyc_ab.apply(align_price, axis = 'columns')

# %%
nyc_ab.loc[:,['price','price_c']]
# Out:
#        price     price_c
# 0        149   -3.720687
# 1        225   72.279313
# 2        150   -2.720687
# 3         89  -63.720687
# 4         80  -72.720687
# 5        200   47.279313
# 6         60  -92.720687
# 7         79  -73.720687
# 8         79  -73.720687
# 9        150   -2.720687
# 10       135  -17.720687
# 11        85  -67.720687
# 12        89  -63.720687
# 13        85  -67.720687
# 14       120  -32.720687
# 15       140  -12.720687
# 16       215   62.279313
# 17       140  -12.720687
# 18        99  -53.720687
# 19       190   37.279313
# 20       299  146.279313
# 21       130  -22.720687
# 22        80  -72.720687
# 23       110  -42.720687
# 24       120  -32.720687
# 25        60  -92.720687
# 26        80  -72.720687
# 27       150   -2.720687
# 28        44 -108.720687
# 29       180   27.279313
# ...      ...         ...
# 48865     80  -72.720687
# 48866     58  -94.720687
# 48867     25 -127.720687
# 48868     25 -127.720687
# 48869     45 -107.720687
# ...

# %%
nyc_ab['price_d'] = nyc_ab['price'] - nyc_ab.price.mean()

# %%
nyc_ab.loc[:,['price','price_c','price_d']]
# Out:
#        price     price_c     price_d
# 0        149   -3.720687   -3.720687
# 1        225   72.279313   72.279313
# 2        150   -2.720687   -2.720687
# 3         89  -63.720687  -63.720687
# 4         80  -72.720687  -72.720687
# 5        200   47.279313   47.279313
# 6         60  -92.720687  -92.720687
# 7         79  -73.720687  -73.720687
# 8         79  -73.720687  -73.720687
# 9        150   -2.720687   -2.720687
# 10       135  -17.720687  -17.720687
# 11        85  -67.720687  -67.720687
# 12        89  -63.720687  -63.720687
# 13        85  -67.720687  -67.720687
# 14       120  -32.720687  -32.720687
# 15       140  -12.720687  -12.720687
# 16       215   62.279313   62.279313
# 17       140  -12.720687  -12.720687
# 18        99  -53.720687  -53.720687
# 19       190   37.279313   37.279313
# 20       299  146.279313  146.279313
# 21       130  -22.720687  -22.720687
# 22        80  -72.720687  -72.720687
# 23       110  -42.720687  -42.720687
# ...

# %%
nyc_ab.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
nyc_ab.groupby('neighbourhood_group').number_of_reviews.count()
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# Name: number_of_reviews, dtype: int64

# %%
nyc_ab.groupby('room_type').price.max()
# Out:
# room_type
# Entire home/apt    0
# Private room       0
# Shared room        0
# Name: price, dtype: int64

# %%
nyc_ab.groupby(['neighbourhood_group','neighbourhood']).apply(lambda df: df.loc[df.price.idxmax()])
# Out:
#                                              id  \
# neighbourhood_group neighbourhood
# Bronx               Allerton            5046189
#                     Baychester         32789261
#                     Belmont            30948241
#                     Bronxdale          19081224
#                     Castle Hill        36350210
#                     City Island        36177241
#                     Claremont Village  36080023
#                     Clason Point       36283398
#                     Co-op City          2628191
#                     Concourse            525293
#                     Concourse Village  15069131
#                     East Morrisania    31089253
#                     Eastchester        27526997
#                     Edenwald           25354678
#                     Fieldston          16428383
#                     Fordham            34544304
#                     Highbridge         23613688
#                     Hunts Point        29287113
# ...

# %%
nyc_ab.groupby(['neighbourhood_group','neighbourhood']).price.agg([min,max])
# Out:
#                                        min   max
# neighbourhood_group neighbourhood
# Bronx               Allerton            33   450
#                     Baychester          53   101
#                     Belmont             24   299
#                     Bronxdale           25   100
#                     Castle Hill         38   128
#                     City Island         29  1000
#                     Claremont Village   26   390
#                     Clason Point        40   379
#                     Co-op City          75    80
#                     Concourse           35   250
#                     Concourse Village   34   159
#                     East Morrisania      0   200
#                     Eastchester         45   475
#                     Edenwald            42   149
#                     Fieldston           49   135
#                     Fordham             21   223
#                     Highbridge          10   240
# ...

# %%
nyc_ab_by_neigh = nyc_ab.groupby(['neighbourhood_group','neighbourhood']).apply(lambda df: df.loc[df.price.idxmax()])

# %%
nyc_ab_by_neigh.sort_values(by='price',ascending = False)
# Out:
#                                                       id  \
# neighbourhood_group neighbourhood
# Queens              Astoria                      7003697
# Manhattan           Upper West Side             22436899
# Brooklyn            Greenpoint                  13894339
# Manhattan           East Harlem                  4737930
#                     Lower East Side              9528920
#                     Tribeca                     23377410
# Brooklyn            Clinton Hill                 2953058
# Manhattan           Upper East Side             22779726
#                     Battery Park City           33007610
# Brooklyn            East Flatbush               34895693
# Manhattan           Chelsea                     33998396
#                     Greenwich Village           12520066
#                     Little Italy                 2243699
#                     Midtown                     33397385
# Brooklyn            Bedford-Stuyvesant           2919330
# ...

# %%
nyc_ab.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# state                              object
# price_c                           float64
# price_d                           float64
# dtype: object

# %%
sum(pd.isnull(nyc_ab.name))
# Out:
# 16

# %%
nyc_ab_nan = nyc_ab[pd.isnull(nyc_ab.name)]

# %%
nyc_ab_nan = nyc_ab_nan.name.fillna('No Name')

# %%
nyc_ab_nan
# Out:
# 2854     No Name
# 3703     No Name
# 5775     No Name
# 5975     No Name
# 6269     No Name
# 6567     No Name
# 6605     No Name
# 8841     No Name
# 11963    No Name
# 12824    No Name
# 13059    No Name
# 13401    No Name
# 15819    No Name
# 16071    No Name
# 18047    No Name
# 28889    No Name
# Name: name, dtype: object

# %%
sum(pd.isnull(nyc_ab.name))
# Out:
# 16

# %%
nyc_ab.name.replace("NaN","No Name")
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
# 5                Large Cozy 1 BR Apartment In Midtown East
# 6                                          BlissArtsSpace!
# 7                         Large Furnished Room Near B'way
# 8                       Cozy Clean Guest Room - Family Apt
# 9                       Cute & Cozy Lower East Side 1 bdrm
# 10                        Beautiful 1br on Upper West Side
# 11                         Central Manhattan/near Broadway
# 12          Lovely Room 1, Garden, Best Area, Legal rental
# 13        Wonderful Guest Bedroom in Manhattan for SINGLES
# 14                           West Village Nest - Superhost
# 15                        Only 2 stops to Manhattan studio
# ...

# %%
sum(pd.isnull(nyc_ab.name))
# Out:
# 16

# %%
nyc_ab.rename(columns={'name':'Name'})
# Out:
#              id                                               Name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
ken_ab = nyc_ab[nyc_ab.neighbourhood == 'Kensington'][['name','neighbourhood','room_type','price']]

# %%
wil_ab = nyc_ab[nyc_ab.neighbourhood == 'Williamsburg'][['name','neighbourhood','room_type','price']]

# %%
pd.concat([ken_ab,wil_ab])
# Out:
#                                                     name neighbourhood  \
# 0                     Clean & quiet apt home by the park    Kensington
# 258                       Large and Cozy Private Bedroom    Kensington
# 397                   SUPER BIG AND COZY PRIVATE BEDROOM    Kensington
# 738                Private clean pleasant spacious room.    Kensington
# 786                  Kensington/Ditmas Park pied-a-terre    Kensington
# 879                  Come and go as  you please in BKLN!    Kensington
# 1074                  Spacious 4 bedroom house, New York    Kensington
# 1212                                 Lovely Brooklyn Apt    Kensington
# 1465      QUIET, SPACIOUS, COMFORTABLE, & GREAT LOCATION    Kensington
# 1814          Vintage Chic Haven in Kensington, Brooklyn    Kensington
# 1926                     Gorgeous 1BR near Prospect Park    Kensington
# 1989            Fully Updated Modern 1 Bedroom Apartment    Kensington
# ...
